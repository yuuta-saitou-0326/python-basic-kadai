# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for planet in array:
    print(planet)

i = 0

while array[i] != array:
    print(array[i])
    if array[i] == 8:
        break
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2-2364890357.py in <cell line: 0>()
#       6 i = 0
#       7
# ----> 8 while array[i] != array:
#       9     print(array[i])
#      10     if array[i] == 8:
#
# IndexError: list index out of range
